# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import cdd
from modulus_tools import demo_graphs
from modulus_tools import algorithms as alg
from itertools import product
# %matplotlib inline
import matplotlib.pyplot as plt
import networkx as nx
from modulus_tools.basic_algorithm import matrix_modulus, modulus
from modulus_tools.families.networkx_families import MinimumSpanningTree

# %%
G, pos = demo_graphs.slashed_house_graph()
m = len(G.edges())
mst = MinimumSpanningTree(G)
#pos = nx.spring_layout(G)
mod, cons, rho, lam = modulus(m, matrix_modulus, mst,  max_iter=400)
eta = rho/mod
s= 1/max(eta)
print('streng= ',s)
print('eta ',eta)
# Out:
# streng=  1.7499999999999998
# eta  [0.57142857 0.57142857 0.57142857 0.57142857 0.57142857 0.57142857
#  0.57142857]

# %%
G, pos = demo_graphs.slashed_house_graph()
m = len(G.edges())
si = [1,2,4,3,1,4,1]
mst = MinimumSpanningTree(G)
#pos = nx.spring_layout(G)
mod, cons, rho, lam = modulus(m, matrix_modulus, mst, sigma= si,  max_iter=400)
print(rho)
# Out:
# [0.41772152 0.27848101 0.15189873 0.15189873 0.41772152 0.15189873
#  0.27848101]

# %%
#G= nx.Graph()
#nx.add_path(G,(0,1,2,3,0))
#nx.add_path(G,(1,3,2,5,2,0,4,5))


for i  in range(2):
    #G = nx.random_geometric_graph(4, 0.5, seed = i+10)
    G, pos = demo_graphs.slashed_house_graph()
    m = len(G.edges())
    si = np.random.rand(m)
    mst = MinimumSpanningTree(G)
    #pos = nx.spring_layout(G)
    mod, cons, rho, lam = modulus(m, matrix_modulus, mst, sigma= si,  max_iter=400)
    eta = rho/mod
    s= 1/max(eta)
    print('streng= ',s)
    mod, cons, rho, lam = modulus(m, matrix_modulus, mst,p=1,sigma= si, max_iter=400)
    #plt.figure(figsize=(5,5))
    #nx.draw(G, pos, node_size=50, node_color='black', width=2, edge_color=np.around(rho,10), edge_cmap=plt.cm.Set2)
    eta = rho/mod
    print('mod = ',mod)
    print('c')
# Out:
# streng=  0.743989046068238
# mod =  0.7439887302659003
# c
# streng=  0.4493311322601422
# mod =  0.4493176604492882
# c

# %%
for i  in range(5):
    n=4
    G = nx.random_geometric_graph(n, 0.5, seed = i+10)
    m = len(G.edges())
    si = np.random.rand(m)
    
    mst = MinimumSpanningTree(G)
    pos = nx.spring_layout(G)
    mod, cons, rho, lam = modulus(m, matrix_modulus, mst, sigma= si,  max_iter=400)
    eta = rho/mod
    the = sum(si)/(n-1)
    print('theta = ',the)
    s= 1/max(eta)
    de = 1/min(eta)
    print('streng= ',s)
    print('denseness= ',de)
    print('(s+de)/2=',(s+de)/2)
    
    mod, cons, rho, lam = modulus(m, matrix_modulus, mst,p=1,sigma= si, max_iter=400)
    #plt.figure(figsize=(5,5))
    #nx.draw(G, pos, node_size=50, node_color='black', width=2, edge_color=np.around(rho,10), edge_cmap=plt.cm.Set2)
    eta = rho/mod
    print('mod1 = ',mod)
    print('NEXT')
# Out:
# theta =  0.9713190815865924
# streng=  0.9667992994739015
# denseness=  0.9735789726429382
# (s+de)/2= 0.9701891360584198
# mod1 =  0.9668001334022271
# NEXT
# theta =  0.8658704186937193
# streng=  0.8423858125266892
# denseness=  0.9128396310277795
# (s+de)/2= 0.8776127217772344
# mod1 =  0.8423858125266892
# NEXT
# theta =  0.13366068286938812
# streng=  0.40098204860816433
# denseness=  0.40098204860816433
# (s+de)/2= 0.40098204860816433
# mod1 =  0.40098204860816433
# NEXT
# theta =  0.9874599857797496
# streng=  0.8308712555062513
# denseness=  1.0657543509164986
# (s+de)/2= 0.948312803211375
# mod1 =  0.8308706518844289
# NEXT
# theta =  0.381539815131001
# streng=  0.3136276081867582
# denseness=  0.8309918372062449
# (s+de)/2= 0.5723097226965016
# mod1 =  0.31362760818675817
# NEXT

# %%
# importing the required module
import matplotlib.pyplot as plt
fig = plt.figure()
ax = plt.axes(projection='3d')
# Data for a three-dimensional line
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'gray')

# Data for three-dimensional scattered points
zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Greens');



plt.savefig("dom.PDF", format="PDF")

# %%
x= []
y= []
z= []
for i  in range(5):
    
    #G = nx.random_geometric_graph(n, 1, seed = i+10)
    G= nx.Graph()
    nx.add_path(G,[0,1,2,0])
    #nx.add_path(G,[0,3])
    n = len(G.nodes())
    m = len(G.edges())
    si = np.random.rand(m)
    mst = MinimumSpanningTree(G)
    pos = nx.spring_layout(G)
    mod, cons, rho, lam = modulus(m, matrix_modulus, mst, sigma= si,  max_iter=400)
    eta = rho/mod
    
    theta  = sum(si)/(n-1)
    z.append(theta)
    stre = 1/max(eta)
    x.append(stre)
    den  = 1/min(eta)
    y.append(den)
    
    
    mod, cons, rho, lam = modulus(m, matrix_modulus, mst,p=1,sigma= si, max_iter=400)
    #plt.figure(figsize=(5,5))
    #nx.draw(G, pos, node_size=50, node_color='black', width=2, edge_color=np.around(rho,10), edge_cmap=plt.cm.Set2)
    eta = rho/mod

# importing the required module
print('x=',x)
print('y=',y)
print('z=',z)
print('figure')
print('plot3(x,y,z)')
import matplotlib.pyplot as plt
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot3D(x, y, z, 'gray')
# Out:
# x= [0.6882773776732332, 0.5819978314929618, 0.4699815628187796, 0.5591810904448784, 0.5850067294299918]
# y= [0.6882773776732332, 0.7032160059535092, 0.9809062169000826, 0.8053022300072282, 0.8950210492947404]
# z= [0.6882773776732332, 0.6426069187232355, 0.725443889859431, 0.6822416602260533, 0.7400138893623662]
# figure
# plot3(x,y,z)
